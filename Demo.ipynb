# %% [markdown]
# <a href="https://colab.research.google.com/github/Szymkie/demo/blob/main/Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#to jest testowe polecenie
x=1+3
print(x)
# Out:
# 4

# %%
#jest to drugie polecenie
print('hehe')
# Out:
# hehe
